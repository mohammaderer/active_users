# %%
import tokenize
import pydriller as pyd
import pandas as pd
from datetime import datetime
import ast

# %%
names=['Alex Ott','Antti Haapala','Bogdan Popa','Brian Larsen','Bryan Oakley',
       'Charles Merriam','Daniel Stenberg','Harry Moreno','Hendy Irawan',
       'Honza Javorek','Justin Ludwig','Ken Williams','Kevin Burke','Kiran Jonnalagadda','Leonardo Costa','Loïc Faure-Lacroix',
      'Marcello de Sales','Mathias Bynens','Matt Sanders','Matthew Schinckel','Matthijs Kooijman','Mike Fiedler',
       'Nick Johnson','Robert Hensing','Seth Tisue','Tuan Anh Tran']

# %%
link = ['https://github.com/ceefour/WordOps.git','https://github.com/ceefour/erpnext.git','https://github.com/ceefour/frappe.git','https://github.com/ceefour/bench.git','https://github.com/ceefour/helm.git','https://github.com/ceefour/nginx-proxy.git','https://github.com/ceefour/zulip.git','https://github.com/ceefour/Zappa.git','https://github.com/ceefour/django-qartez.git','https://github.com/ceefour/readthedocs.org.git','https://github.com/ceefour/google-code-issues-migrator.git']

# %%
link = ['https://github.com/ceefour/WordOps.git','https://github.com/ceefour/erpnext.git','https://github.com/ceefour/frappe.git','https://github.com/ceefour/bench.git','https://github.com/ceefour/helm.git','https://github.com/ceefour/nginx-proxy.git','https://github.com/ceefour/zulip.git','https://github.com/ceefour/Zappa.git','https://github.com/ceefour/django-qartez.git','https://github.com/ceefour/readthedocs.org.git','https://github.com/ceefour/google-code-issues-migrator.git',
'https://github.com/honzajavorek/honzajavorek.cz.git','https://github.com/honzajavorek/czech-political-parties.git','https://github.com/honzajavorek/cojeapi.git','https://github.com/honzajavorek/foto.git','https://github.com/honzajavorek/rtd-redirects.git','https://github.com/honzajavorek/prazeni.honzajavorek.cz.git','https://github.com/honzajavorek/czech-holidays.git','https://github.com/honzajavorek/danube-delta.git','https://github.com/honzajavorek/fiobank.git','https://github.com/honzajavorek/mkdocs_macros_plugin.git','https://github.com/honzajavorek/ih-interviews.git','https://github.com/honzajavorek/mkdocs-simple-hooks.git','https://github.com/honzajavorek/mkdocs-jinja2.git','https://github.com/honzajavorek/prompt.git','https://github.com/honzajavorek/Frozen-Flask.git','https://github.com/honzajavorek/pycapital.git','https://github.com/honzajavorek/sendgrid-python.git','https://github.com/honzajavorek/webring.git','https://github.com/honzajavorek/emojicodes.git','https://github.com/honzajavorek/py.git','https://github.com/honzajavorek/schedule-tweet.git','https://github.com/honzajavorek/markdown-del-ins.git','https://github.com/honzajavorek/sphinx-tabs.git','https://github.com/honzajavorek/bude-hezky.git','https://github.com/honzajavorek/pyvec.org.git','https://github.com/honzajavorek/oci-cli.git','https://github.com/honzajavorek/eject.git','https://github.com/honzajavorek/biska.git','https://github.com/honzajavorek/black.git','https://github.com/honzajavorek/sphinx.git','https://github.com/honzajavorek/recommonmark.git','https://github.com/honzajavorek/python-semantic-release.git','https://github.com/honzajavorek/deoraclize.git','https://github.com/honzajavorek/tit.git','https://github.com/honzajavorek/call-me-maybe.git','https://github.com/honzajavorek/oleander.git','https://github.com/honzajavorek/brno.git','https://github.com/honzajavorek/finances.git','https://github.com/honzajavorek/sa-calendar.git','https://github.com/honzajavorek/tripme.git','https://github.com/honzajavorek/tipi.git','https://github.com/honzajavorek/zdrojak-json-schema.git',
'https://github.com/justinludwig/j3status.git','https://github.com/justinludwig/ansible.git','https://github.com/justinludwig/pydocstyle.git','https://github.com/justinludwig/flake8-expression-complexity.git','https://github.com/justinludwig/flake8-class-attributes-order.git','https://github.com/justinludwig/flake8-requirements.git','https://github.com/justinludwig/numpydoc.git','https://github.com/justinludwig/mutt-ical.git','https://github.com/justinludwig/powerline-svnstatus.git','https://github.com/justinludwig/queuesplugin.git',
'https://github.com/kenahoo/hydra.git','https://github.com/kenahoo/gise-2020.git','https://github.com/kenahoo/recurrent.git','https://github.com/kenahoo/Banktivity-Export.git','https://github.com/kenahoo/xlsx2csv.git','https://github.com/kenahoo/docs.git',
'https://github.com/kevinburke/weirdfortune.git','https://github.com/kevinburke/gitopen.git','https://github.com/kevinburke/flask-restless.git','https://github.com/kevinburke/rules_node.git','https://github.com/kevinburke/cryptography.git','https://github.com/kevinburke/hamms.git','https://github.com/kevinburke/ansible.git','https://github.com/kevinburke/ansible-modules-core.git','https://github.com/kevinburke/list.git','https://github.com/kevinburke/requests.git','https://github.com/kevinburke/letsencrypt.git','https://github.com/kevinburke/attendee-notes.git','https://github.com/kevinburke/urllib3.git','https://github.com/kevinburke/autojump.git','https://github.com/kevinburke/stubhub-tickets.git','https://github.com/kevinburke/pip.git','https://github.com/kevinburke/cachecontrol.git','https://github.com/kevinburke/scripttest.git','https://github.com/kevinburke/twilio-python.git','https://github.com/kevinburke/bitsquat.git','https://github.com/kevinburke/httpie.git','https://github.com/kevinburke/werkzeug.git','https://github.com/kevinburke/lxml.git','https://github.com/kevinburke/twilio-jsonapi.git','https://github.com/kevinburke/downanddistance.git','https://github.com/kevinburke/ipython.git','https://github.com/kevinburke/flask.git','https://github.com/kevinburke/snapchat-friends.git','https://github.com/kevinburke/nose.git','https://github.com/kevinburke/Twilio-Hackpack-for-Heroku-and-Flask.git','https://github.com/kevinburke/readthedocs.org.git','https://github.com/kevinburke/jenkins.git','https://github.com/kevinburke/flask-restful.git','https://github.com/kevinburke/boto.git','https://github.com/kevinburke/python-phonenumbers.git','https://github.com/kevinburke/gae_bingo.git','https://github.com/kevinburke/goodmorningcmc.git','https://github.com/kevinburke/Testify.git','https://github.com/kevinburke/popfly.git','https://github.com/kevinburke/django-twilio.git','https://github.com/kevinburke/python-guide.git','https://github.com/kevinburke/virtualenv.git','https://github.com/kevinburke/telapi-python.git','https://github.com/kevinburke/howtos.git','https://github.com/kevinburke/python-hoiio.git','https://github.com/kevinburke/mrjob.git','https://github.com/kevinburke/Twilio-Python-quickstarts.git','https://github.com/kevinburke/python-oauth2.git',
'https://github.com/jace/mxsniff.git','https://github.com/jace/adsorb.git','https://github.com/jace/moviefolder.git','https://github.com/jace/qwkweb.git','https://github.com/jace/ljpics.git','https://github.com/jace/pydocflow.git','https://github.com/jace/zine-plugins.git','https://github.com/jace/zine-main.git','https://github.com/jace/flask-themes.git','https://github.com/jace/flask-dogpile.git','https://github.com/jace/lastfirst.git','https://github.com/jace/flask_debugtoolbar_lineprofilerpanel.git','https://github.com/jace/sqlalchemy-utils.git','https://github.com/jace/flask-pyelasticsearch.git','https://github.com/jace/rbc-tcconfig.git','https://github.com/jace/wiki-analysis.git','https://github.com/jace/flask-mail.git','https://github.com/jace/flask-alembic.git','https://github.com/jace/werkzeug.git','https://github.com/jace/flask-wtf.git','https://github.com/jace/python-oauth2.git',
'https://github.com/leocosta/drone_object_detection.git','https://github.com/leocosta/MITMf.git','https://github.com/leocosta/poc-recommender-system.git','https://github.com/leocosta/data_science.git','https://github.com/leocosta/udemy.git',
'https://github.com/llacroix/networked-volume-watchdog.git','https://github.com/llacroix/odoo.git','https://github.com/llacroix/prometheus-swarm-discovery.git','https://github.com/llacroix/openupgrade-docker.git','https://github.com/llacroix/ofxparse.git','https://github.com/llacroix/black.git','https://github.com/llacroix/prometheus-docker-sd.git','https://github.com/llacroix/docker-py.git','https://github.com/llacroix/nfcpy.git','https://github.com/llacroix/connector-prestashop.git','https://github.com/llacroix/odoo-freeze.git','https://github.com/llacroix/pyramid_mongo.git','https://github.com/llacroix/bufferfly.git','https://github.com/llacroix/pyramid_oauth2.git','https://github.com/llacroix/gunicorn.git','https://github.com/llacroix/vrm-interactive-shell.git','https://github.com/llacroix/pyramid_rpc.git','https://github.com/llacroix/Git-Python-Http.git','https://github.com/llacroix/pyramid.git','https://github.com/llacroix/vkapi.git','https://github.com/llacroix/odoo-docker.git',
'https://github.com/marcellodesales/cover2cover-docker.git','https://github.com/marcellodesales/hadoop-clusternet.git','https://github.com/marcellodesales/python.git','https://github.com/marcellodesales/jenkinsapi.git','https://github.com/marcellodesales/rules_k8s.git','https://github.com/marcellodesales/rules_k8s-OLD.git','https://github.com/marcellodesales/kubebot.git','https://github.com/marcellodesales/docker-puller.git','https://github.com/marcellodesales/hadoop-training.git','https://github.com/marcellodesales/haproxy.git','https://github.com/marcellodesales/dockercoins.git','https://github.com/marcellodesales/docker-compose-demo.git','https://github.com/marcellodesales/myscheduler.git','https://github.com/marcellodesales/docker-registry.git','https://github.com/marcellodesales/twissandra.git','https://github.com/marcellodesales/svnedge-console.git','https://github.com/marcellodesales/svnedge-integration-ctf.git','https://github.com/marcellodesales/jasy.git','https://github.com/marcellodesales/jasy-html5-boilerplate.git',
'https://github.com/mathiasbynens/feedvalidator.git','https://github.com/mathiasbynens/chromium-dashboard.git','https://github.com/mathiasbynens/bidiInChromeContext.git','https://github.com/mathiasbynens/covid19-vaccination-subnational.git','https://github.com/mathiasbynens/Impfquotenmonitoring.git','https://github.com/mathiasbynens/clusterfuzz.git','https://github.com/mathiasbynens/NabBot.git','https://github.com/mathiasbynens/node-gyp.git','https://github.com/mathiasbynens/waterfall.git','https://github.com/mathiasbynens/pogocpm2level.git','https://github.com/mathiasbynens/domato.git','https://github.com/mathiasbynens/pogopowerupcost.git','https://github.com/mathiasbynens/RocketMap.git','https://github.com/mathiasbynens/browserscope.git','https://github.com/mathiasbynens/pogotransfercalc.git','https://github.com/mathiasbynens/es-spec-html.git','https://github.com/mathiasbynens/pwntools.git',
'https://github.com/nextmat/python-librato.git',
'https://github.com/morenoh149/django-add-field-then-change.git','https://github.com/morenoh149/djangox-autocomplete-light.git','https://github.com/morenoh149/django-splitdatetimefield.git','https://github.com/morenoh149/djangox-leaflet-demo.git','https://github.com/morenoh149/web3.py.git','https://github.com/morenoh149/django-rest-framework-getstream.git','https://github.com/morenoh149/django-flaggit.git','https://github.com/morenoh149/interview_question_data.git','https://github.com/morenoh149/interview_question_python.git','https://github.com/morenoh149/django-rest-datatables-relations-example.git','https://github.com/morenoh149/django-rest-framework-datatables.git','https://github.com/morenoh149/en-es-en-Dic.git','https://github.com/morenoh149/django-autocomplete-light.git','https://github.com/morenoh149/pdf2image.git','https://github.com/morenoh149/django-pg-zero-downtime-migrations.git','https://github.com/morenoh149/celery.git','https://github.com/morenoh149/django-avatar.git','https://github.com/morenoh149/django-bootstrap-datepicker-plus.git','https://github.com/morenoh149/django-crispy-forms.git','https://github.com/morenoh149/Auto_ViML.git','https://github.com/morenoh149/pandas.git','https://github.com/morenoh149/cookiecutter-django.git','https://github.com/morenoh149/bitcoinbook.git','https://github.com/morenoh149/build-app-with-python-antitextbook.git','https://github.com/morenoh149/statsmodels.git','https://github.com/morenoh149/kaggle-nyc.git','https://github.com/morenoh149/graphene.git','https://github.com/morenoh149/tornado.git','https://github.com/morenoh149/django-allauth.git','https://github.com/morenoh149/scrapy.git','https://github.com/morenoh149/scraping_project.git','https://github.com/morenoh149/django-project-template.git','https://github.com/morenoh149/Snkrs-Bot.git','https://github.com/morenoh149/cookiecutter-django-rest.git','https://github.com/morenoh149/simple-keras-rest-api.git','https://github.com/morenoh149/django.git','https://github.com/morenoh149/python-docs-samples.git','https://github.com/morenoh149/python_speech_features.git','https://github.com/morenoh149/keras.git','https://github.com/morenoh149/kombu.git','https://github.com/morenoh149/flask.git','https://github.com/morenoh149/flaskr.git','https://github.com/morenoh149/buildbot.git','https://github.com/morenoh149/django-rest-framework-json-api.git','https://github.com/morenoh149/awesome-machine-learning.git','https://github.com/morenoh149/supervising-ui.git','https://github.com/morenoh149/django-diy-blog.git','https://github.com/morenoh149/django-locallibrary-tutorial.git','https://github.com/morenoh149/harrymoreno_backend.git','https://github.com/morenoh149/django-extensions.git','https://github.com/morenoh149/arrow.git','https://github.com/morenoh149/customer_support_substitute.git','https://github.com/morenoh149/ML-From-Scratch.git','https://github.com/morenoh149/MLAlgorithms.git','https://github.com/morenoh149/littleHospital.git','https://github.com/morenoh149/piprot.git','https://github.com/morenoh149/spellcheck_py.git','https://github.com/morenoh149/NYCPythonSOH.git','https://github.com/morenoh149/tddwp.git','https://github.com/morenoh149/pythonConcurrencyFromTheGroundUp.git','https://github.com/morenoh149/aosaOCR.git','https://github.com/morenoh149/djangoTutorial.git','https://github.com/morenoh149/djangoRestFrameworkTutorial.git','https://github.com/morenoh149/AutoViz.git','https://github.com/morenoh149/amazon-sagemaker-examples.git','https://github.com/morenoh149/tensorflow-sagemaker.git','https://github.com/morenoh149/keras_to_tensorflow.git','https://github.com/morenoh149/plantdisease.git','https://github.com/morenoh149/dog-breeds-classifier.git','https://github.com/morenoh149/DATA-SCIENCE-BOWL-2018.git','https://github.com/morenoh149/deeplearning.git','https://github.com/morenoh149/WhirlwindTourOfPython.git',
'https://github.com/schinckel/django-keyset-pagination.git','https://github.com/schinckel/django-shared-property.git','https://github.com/schinckel/tuya-convert.git','https://github.com/schinckel/django.git','https://github.com/schinckel/django-closure-tree.git','https://github.com/schinckel/django-computed-field.git','https://github.com/schinckel/SMB35.git','https://github.com/schinckel/pyxero.git','https://github.com/schinckel/celery-once.git','https://github.com/schinckel/authlib.git','https://github.com/schinckel/django-otp.git','https://github.com/schinckel/django-two-factor-auth.git','https://github.com/schinckel/rubyenv.git','https://github.com/schinckel/rinse.git','https://github.com/schinckel/django-cbv-inspector.git','https://github.com/schinckel/robotframework-debuglibrary.git','https://github.com/schinckel/robotframework-djangolibrary.git','https://github.com/schinckel/webdriver_manager.git','https://github.com/schinckel/sentry-python.git',
'https://github.com/matthijskooijman/django.git','https://github.com/matthijskooijman/documentation.git','https://github.com/matthijskooijman/radicale-imap.git','https://github.com/matthijskooijman/Pinout.xyz.git','https://github.com/matthijskooijman/weechat-matrix.git','https://github.com/matthijskooijman/hamster.git','https://github.com/matthijskooijman/svg2mod.git','https://github.com/matthijskooijman/nfcpy.git','https://github.com/matthijskooijman/AdbPaste.git','https://github.com/matthijskooijman/nml.git','https://github.com/matthijskooijman/python-omxplayer-wrapper.git','https://github.com/matthijskooijman/matplotlib.git','https://github.com/matthijskooijman/willie.git','https://github.com/matthijskooijman/arduino-mass-builder.git',
'https://github.com/miketheman/sqlfluff.git','https://github.com/miketheman/pytest-socket.git','https://github.com/miketheman/cookiecutter-fastapi-serverless.git','https://github.com/miketheman/unsilencer.git','https://github.com/miketheman/warehouse.git','https://github.com/miketheman/pydantic.git','https://github.com/miketheman/python-private-packages.git','https://github.com/miketheman/libyear.git','https://github.com/miketheman/redash.git','https://github.com/miketheman/django.git','https://github.com/miketheman/sentry.git','https://github.com/miketheman/dd-agent.git','https://github.com/miketheman/pre-commit-hooks.git','https://github.com/miketheman/python-zeep.git','https://github.com/miketheman/datadogpy.git',
'https://github.com/Arachnid/brewblox-tilt.git','https://github.com/Arachnid/pyqrencode.git','https://github.com/Arachnid/bloggart.git','https://github.com/Arachnid/web3.py.git','https://github.com/Arachnid/aiodataloader.git','https://github.com/Arachnid/slips.git','https://github.com/Arachnid/ethjsonrpc.git','https://github.com/Arachnid/python-trezor.git','https://github.com/Arachnid/pyethapp.git','https://github.com/Arachnid/python-keepkey.git','https://github.com/Arachnid/advisor.git','https://github.com/Arachnid/dfpga.git','https://github.com/Arachnid/shell.git','https://github.com/Arachnid/exabrot.git',
'https://github.com/roberth/nixpkgs-review.git','https://github.com/roberth/Arelle.git',
'https://github.com/alexott/databricks-nutter-projects-demo.git','https://github.com/alexott/fastbook.git','https://github.com/alexott/courses.git','https://github.com/alexott/databricks-cli.git','https://github.com/alexott/dbx.git','https://github.com/alexott/nutter.git','https://github.com/alexott/test-repos.git','https://github.com/alexott/cicd-templates.git','https://github.com/alexott/databricks-api.git','https://github.com/alexott/splunk-integration.git','https://github.com/alexott/mlflow.git','https://github.com/alexott/chispa.git','https://github.com/alexott/nlp_model_selection_app.git','https://github.com/alexott/nlu.git','https://github.com/alexott/db-demo-project.git','https://github.com/alexott/databricks-cicd-definitelynotademo.git','https://github.com/alexott/migrate.git','https://github.com/alexott/TwitterSentiment.git','https://github.com/alexott/NETL-Automatic-Topic-Labelling-.git','https://github.com/alexott/PyTorch-NLP.git','https://github.com/alexott/empythy.git',
'https://github.com/ztane/cpython.git','https://github.com/ztane/peps.git','https://github.com/ztane/pyramid_mailer.git','https://github.com/ztane/advent2020.git','https://github.com/ztane/wired.git','https://github.com/ztane/pyramid.git','https://github.com/ztane/ps_alchemy.git','https://github.com/ztane/sqlalchemy.git','https://github.com/ztane/sqlalchemy-1.git','https://github.com/ztane/aoc2018.git','https://github.com/ztane/pyramid-admin.git','https://github.com/ztane/warehouse.git','https://github.com/ztane/pyramid_debugtoolbar.git','https://github.com/ztane/hls_downloader.git','https://github.com/ztane/aoc2017.git','https://github.com/ztane/advent-of-code-data.git','https://github.com/ztane/pyramid_rpc.git','https://github.com/ztane/plaster_pastedeploy.git','https://github.com/ztane/junison.git','https://github.com/ztane/adventofcode.git','https://github.com/ztane/peacock.git','https://github.com/ztane/virtualenv.git','https://github.com/ztane/slimit.git','https://github.com/ztane/colander.git','https://github.com/ztane/phpserialize.git','https://github.com/ztane/jaspyx.git','https://github.com/ztane/pyramid_tutorials.git','https://github.com/ztane/Tonnikala.git','https://github.com/ztane/jython3.git','https://github.com/ztane/pika.git','https://github.com/ztane/jinja2.git','https://github.com/ztane/pjpersist.git','https://github.com/ztane/streams.git','https://github.com/ztane/boto.git','https://github.com/ztane/pyramid_django.git','https://github.com/ztane/zsos.git','https://github.com/ztane/relstorage.git','https://github.com/ztane/wabbit_wappa.git','https://github.com/ztane/caerbannog.git','https://github.com/ztane/pyramid_celery.git','https://github.com/ztane/appenlight-client-python.git','https://github.com/ztane/python-escpos.git','https://github.com/ztane/tet_admin.git','https://github.com/ztane/SpiffWorkflow.git','https://github.com/ztane/mako.git','https://github.com/ztane/pyconfi2013.git','https://github.com/ztane/transaction.git','https://github.com/ztane/zope.sqlalchemy.git','https://github.com/ztane/mypy.git','https://github.com/ztane/hiero.git',
'https://github.com/Bogdanp/dramatiq.git','https://github.com/Bogdanp/dramatiq_dashboard.git','https://github.com/Bogdanp/django_dramatiq.git','https://github.com/Bogdanp/dramatiq_sqs.git','https://github.com/Bogdanp/molten.git','https://github.com/Bogdanp/cursive_re.git','https://github.com/Bogdanp/molten_chat_ws.git','https://github.com/Bogdanp/django_dramatiq_example.git','https://github.com/Bogdanp/hugs.git','https://github.com/Bogdanp/et.git','https://github.com/Bogdanp/flask_dramatiq_example.git','https://github.com/Bogdanp/anom-py.git','https://github.com/Bogdanp/fargate_scraper.git','https://github.com/Bogdanp/watchdog_gevent.git','https://github.com/Bogdanp/resource_pool.git','https://github.com/Bogdanp/web-app-from-scratch.git','https://github.com/Bogdanp/molten_cookiecutter.git','https://github.com/Bogdanp/apistar.git','https://github.com/Bogdanp/apistar_request_id.git','https://github.com/Bogdanp/threadop.git','https://github.com/Bogdanp/apistar_prometheus.git','https://github.com/Bogdanp/falcon_sugar.git','https://github.com/Bogdanp/heater.git','https://github.com/Bogdanp/apistar_sentry.git','https://github.com/Bogdanp/apistar_settings.git','https://github.com/Bogdanp/apistar_cors.git','https://github.com/Bogdanp/apistar_dramatiq.git','https://github.com/Bogdanp/dramatiq_ecommerce_demo.git','https://github.com/Bogdanp/django_dramatiq_pdfapi_example.git','https://github.com/Bogdanp/h2p.git','https://github.com/Bogdanp/kawa.git','https://github.com/Bogdanp/multiprom.git','https://github.com/Bogdanp/yes.py.git','https://github.com/Bogdanp/markii.git','https://github.com/Bogdanp/trio-redis.git','https://github.com/Bogdanp/pico.git','https://github.com/Bogdanp/mold.git','https://github.com/Bogdanp/cedar.git','https://github.com/Bogdanp/urweb-starterkit.git','https://github.com/Bogdanp/modviz.git','https://github.com/Bogdanp/tcopy.git','https://github.com/Bogdanp/cobra.git','https://github.com/Bogdanp/ymage.git','https://github.com/Bogdanp/pirate.git','https://github.com/Bogdanp/pyline.git',
'https://github.com/brl0/geopandas.git','https://github.com/brl0/gcsfs.git','https://github.com/brl0/ipython.git','https://github.com/brl0/ipython.git','https://github.com/brl0/universal_pathlib.git','https://github.com/brl0/cloudpickle.git','https://github.com/brl0/filesystem_spec.git','https://github.com/brl0/dask.git','https://github.com/brl0/hvplot.git','https://github.com/brl0/dask-gateway.git','https://github.com/brl0/holoviews.git','https://github.com/brl0/panel.git','https://github.com/brl0/pandas.git','https://github.com/brl0/primesieve-python.git','https://github.com/brl0/spatialpandas.git','https://github.com/brl0/dateparser.git','https://github.com/brl0/statsmodels.git','https://github.com/brl0/extraction_tutorial.git','https://github.com/brl0/bonked.git','https://github.com/brl0/bripy.git','https://github.com/brl0/imported.git','https://github.com/brl0/Python.git','https://github.com/brl0/kartothek.git','https://github.com/brl0/datacamp_courses.git','https://github.com/brl0/conda.git','https://github.com/brl0/examinator.git','https://github.com/brl0/sudoku.git','https://github.com/brl0/data-jam-december-2019.git','https://github.com/brl0/brl0-stuff.git','https://github.com/brl0/conda-lock.git','https://github.com/brl0/staged-recipes.git','https://github.com/brl0/multi-ping.git','https://github.com/brl0/extraction.git','https://github.com/brl0/validators.git','https://github.com/brl0/konch.git','https://github.com/brl0/TTF-to-PNG.git',
'https://github.com/boakley/robotframework-pageobjectlibrary.git','https://github.com/boakley/robotframework-hub.git','https://github.com/boakley/robotframework-workbench.git','https://github.com/boakley/robotframework-lightning.git','https://github.com/boakley/robotframework.git','https://github.com/boakley/Selenium2Library.git','https://github.com/boakley/talos.git',
'https://github.com/merriam/columns.git','https://github.com/merriam/markdown.git','https://github.com/merriam/BrachioGraph.git','https://github.com/merriam/tutorial_2019_asyncio.git','https://github.com/merriam/blessings.git','https://github.com/merriam/persistent.git','https://github.com/merriam/data.git','https://github.com/merriam/fastai_ml1_python3.git','https://github.com/merriam/multiprocess.git','https://github.com/merriam/gspread.git','https://github.com/merriam/Pillow.git','https://github.com/merriam/cairocffi.git','https://github.com/merriam/kivy.git','https://github.com/merriam/colorama.git','https://github.com/merriam/docfile.git','https://github.com/merriam/vpython-wx.git','https://github.com/merriam/urwid.git','https://github.com/merriam/pyUI.git','https://github.com/merriam/python-future.git','https://github.com/merriam/flask.git','https://github.com/merriam/timestamp.git','https://github.com/merriam/package_control_channel.git','https://github.com/merriam/beancount.git','https://github.com/merriam/localtunnel.git','https://github.com/merriam/dectools.git',
'https://github.com/bagder/gitstats.git','https://github.com/bagder/doh-proxy.git','https://github.com/bagder/pycurl.git',
'https://github.com/SethTisue/awesome-scala.git',
'https://github.com/tuananh/endgame.git','https://github.com/tuananh/goodreads_etl_pipeline.git','https://github.com/tuananh/DeepFaceLab.git','https://github.com/tuananh/redisjson-py.git','https://github.com/tuananh/SublimeJsPrettier.git','https://github.com/tuananh/EdgeRealtimeVideoAnalytics.git','https://github.com/tuananh/haxor-news.git','https://github.com/tuananh/distroless.git']

# %%
tf_dt1 = datetime(2018,1, 1)
tf_dt2 = datetime(2021, 9, 22)

# %%
tf_source = pd.DataFrame(columns=['commit_ID', 'Author', 'msg', 'Commit_before','Commit_after','diff'])
for commit in pyd.Repository(path_to_repo=link,since=tf_dt1, to=tf_dt2).traverse_commits():
    if commit.author.name in names:
        for modified_file in commit.modified_files:
            if modified_file.filename.endswith(".py"):
                tf_source=tf_source.append({'Author': commit.author.name,
                                             'Commit_before': modified_file.source_code_before,
                                             'Commit_after': modified_file.source_code,
                                             'diff': modified_file.diff}, ignore_index=True)

# %%
tf_source.to_csv('tokenize_data_2023.csv')

# %%
tf_source.to_csv('tokenize_data.csv')
